# %%
# from neo4j import GraphDatabase

# # URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"
# URI = "neo4j://localhost"
# AUTH = ("<Username>", "<Password>")

# with GraphDatabase.driver(URI, auth=AUTH) as driver:
#     driver.verify_connectivity()

# #----

# summary = driver.execute_query(
#     "CREATE (:Person {name: $name, age: $age})",
#     name="Alice",
#     age=42,
#     database_="neo4j",
# ).summary
# print("Created {nodes_created} nodes in {time} ms.".format(
#     nodes_created=summary.counters.nodes_created,
#     time=summary.result_available_after
# ))

# #----

# # Get the name of all 42 year-olds
# records, summary, keys = driver.execute_query(
#     "MATCH (p:Person {age: $age}) RETURN p.name AS name",
#     age=42,
#     database_="neo4j",
# )

# # Loop through results and do something with them
# for person in records:
#     print(person)

# # Summary information
# print("The query `{query}` returned {records_count} records in {time} ms.".format(
#     query=summary.query, records_count=len(records),
#     time=summary.result_available_after,
# ))

# %%
from dotenv import load_dotenv
import os

# Common data processing
import json
import textwrap

# Langchain
from langchain_community.graphs import Neo4jGraph
from langchain_community.vectorstores import Neo4jVector
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQAWithSourcesChain


# Warning control
import warnings
warnings.filterwarnings("ignore")

# %%
# Connect to local Neo4J database

NEO4J_URI = "neo4j://localhost"
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "admin123"
NEO4J_DATABASE = "neo4j"

kg = Neo4jGraph(
    url=NEO4J_URI, username=NEO4J_USERNAME, password=NEO4J_PASSWORD, database=NEO4J_DATABASE
)

# %%
# Create a sample dataframe
import pandas as pd

# Data for the dataframe
data = {
    'Character': [
        'Luke Skywalker', 'Darth Vader (Anakin)', 'Princess Leia Organa', 'Han Solo', 'Yoda',
        'Obi-Wan Kenobi', 'Palpatine (Emperor)', 'Chewbacca', 'R2-D2', 'C-3PO',
        'Boba Fett', 'Jabba the Hutt', 'Lando Calrissian', 'Padmé Amidala', 'Qui-Gon Jinn',
        'Mace Windu', 'Ahsoka Tano', 'Kylo Ren (Ben Solo)', 'Rey Skywalker', 'Finn',
        'Poe Dameron', 'Count Dooku', 'Darth Maul', 'Jango Fett', 'General Grievous',
        'Rose Tico', 'Captain Phasma', 'BB-8', 'Admiral Ackbar', 'Wedge Antilles',
        'Mon Mothma', 'Ezra Bridger', 'Sabine Wren', 'Kanan Jarrus', 'Grand Admiral Thrawn',
        'Jyn Erso', 'Cassian Andor', 'Chirrut Îmwe', 'Saw Gerrera', 'Orson Krennic'
    ],
    'First Movie': [
        'Star Wars: A New Hope', 'Star Wars: A New Hope', 'Star Wars: A New Hope', 'Star Wars: A New Hope',
        'Star Wars: The Empire Strikes Back', 'Star Wars: A New Hope', 'Star Wars: The Empire Strikes Back', 
        'Star Wars: A New Hope', 'Star Wars: A New Hope', 'Star Wars: A New Hope',
        'Star Wars: The Empire Strikes Back', 'Star Wars: Return of the Jedi', 'Star Wars: The Empire Strikes Back',
        'Star Wars: The Phantom Menace', 'Star Wars: The Phantom Menace', 'Star Wars: The Phantom Menace',
        'Ancient Jedi Master who trained countless Jedi, including Luke Skywalker.',
        'Former Jedi Knight who trained Anakin and later guided Luke in the ways of the Force.',
        'Sith Lord and Emperor of the Galactic Empire, master of Darth Vader.',
        'Wookiee warrior and co-pilot of the Millennium Falcon, fiercely loyal to Han Solo.',
        'Astromech droid who served Anakin and later Luke, played key roles in many battles.',
        'Protocol droid fluent in many languages, companion to R2-D2, built by Anakin Skywalker.',
        'Notorious bounty hunter, son/clone of Jango Fett, and nemesis to Han Solo.',
        'Crime lord based on Tatooine, known for his dealings with bounty hunters and smugglers.',
        'Gambler, smuggler, and old friend of Han Solo who became a key figure in the Rebellion.',
        'Queen of Naboo and later Senator, mother to Luke and Leia, and wife of Anakin Skywalker.',
        'Jedi Master who discovered Anakin Skywalker and believed in the prophecy of the Chosen One.',
        'High-ranking Jedi Master on the Jedi Council, known for his skill with a lightsaber.',
        'Anakin Skywalker\'s Padawan, later a key figure in the Rebellion, and a skilled Jedi.',
        'Son of Han and Leia, conflicted Force user who turned to the dark side, became a Sith.',
        'Scavenger-turned-Jedi, granddaughter of Palpatine, who ultimately restores balance.',
        'Former Stormtrooper who defected to the Resistance and fought alongside Rey and Poe.',
        'Ace pilot of the Resistance, loyal to General Leia Organa, and a key leader in the fight.',
        'Former Jedi who became a Sith Lord, leading the Separatist movement in the Clone Wars.',
        'Sith apprentice to Darth Sidious, known for his double-bladed lightsaber and vengeance.',
        'Bounty hunter and template for the clone army, father/clone of Boba Fett.',
        'Cyborg commander of the Separatist droid army, feared for his lightsaber collection.',
        'Mechanic in the Resistance, inspired by her sister\'s sacrifice, and friend to Finn.',
        'Ruthless commander of the First Order\'s stormtroopers, known for her chrome armor.',
        'Spherical droid belonging to Poe Dameron, key in the Resistance\'s mission against the First Order.',
        'Mon Calamari leader in the Rebel Alliance, known for his tactical expertise ("It\'s a trap!").',
        'Rebel Alliance pilot who fought in major battles including the Death Star and Endor.',
        'Political leader of the Rebel Alliance, instrumental in forming the Rebellion against the Empire.',
        'Orphan-turned-Jedi who fought against the Empire and helped found the Rebel Alliance.',
        'Mandalorian warrior and artist, key member of the Ghost crew fighting the Empire.',
        'Former Jedi Knight who survived Order 66, mentor to Ezra Bridger, and Rebel leader.',
        'Brilliant Imperial strategist, known for his cunning and leadership in the Empire.',
        'Rebel fighter who led the mission to steal the Death Star plans, sacrificing herself in the process.',
        'Rebel spy and captain, key figure in the mission to acquire the Death Star plans.',
        'Blind warrior-monk who believes in the Force, ally to Jyn Erso and Cassian Andor.',
        'Rebel extremist who fought against both the Separatists and the Empire.',
        'Director of the Death Star project for the Empire, rival to Tarkin and other Imperial officers.'
    ],
    'Source':["source"]*40
}

# Create the dataframe
df = pd.DataFrame(data)

# %%
df
# Out:
#                Character                         First Movie  Year  \
# 0         Luke Skywalker               Star Wars: A New Hope  1977
# 1   Darth Vader (Anakin)               Star Wars: A New Hope  1977
# 13  Queen of Naboo and later Senator, mother to Lu...  source
# 14  Jedi Master who discovered Anakin Skywalker an...  source
# 15  High-ranking Jedi Master on the Jedi Council, ...  source
# 16  Anakin Skywalker's Padawan, later a key figure...  source
# 17  Son of Han and Leia, conflicted Force user who...  source
# 18  Scavenger-turned-Jedi, granddaughter of Palpat...  source
# 19  Former Stormtrooper who defected to the Resist...  source
# 20  Ace pilot of the Resistance, loyal to General ...  source
# 21  Former Jedi who became a Sith Lord, leading th...  source
# 22  Sith apprentice to Darth Sidious, known for hi...  source
# 23  Bounty hunter and template for the clone army,...  source
# 24  Cyborg commander of the Separatist droid army,...  source
# 25  Mechanic in the Resistance, inspired by her si...  source
# 26  Ruthless commander of the First Order's stormt...  source
# 27  Spherical droid belonging to Poe Dameron, key ...  source
# 28  Mon Calamari leader in the Rebel Alliance, kno...  source
# 29  Rebel Alliance pilot who fought in major battl...  source
# 30  Political leader of the Rebel Alliance, instru...  source
# 31  Orphan-turned-Jedi who fought against the Empi...  source
# 32  Mandalorian warrior and artist, key member of ...  source
# 33  Former Jedi Knight who survived Order 66, ment...  source
# 34  Brilliant Imperial strategist, known for his c...  source
# 35  Rebel fighter who led the mission to steal the...  source
# 36  Rebel spy and captain, key figure in the missi...  source
# 37  Blind warrior-monk who believes in the Force, ...  source
# 38  Rebel extremist who fought against both the Se...  source
# 39  Director of the Death Star project for the Emp...  source

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 200,
    chunk_overlap  = 20,
    length_function = len,
    is_separator_regex = False,
)

# %%
df.columns
# Out:
# Index(['Character', 'First Movie', 'Year', 'Background Summary', 'Source'], dtype='object')

# %%
def split_data_from_file(df):
    chunks_with_metadata = [] # use this to accumlate chunk records

    for i in range(df.shape[0]):
        print(f'Processing {i}') 
        item_text = df["Background Summary"].iloc[i] # grab the text of the item
        item_text_chunks = text_splitter.split_text(item_text) # split the text into chunks
        chunk_seq_id = 0
        for chunk in item_text_chunks:
            form_id = "star-wars-characters"
            # finally, construct a record with metadata and the chunk text
            chunks_with_metadata.append({
                'text': chunk, 
                # metadata from looping...
                'chunkSeqId': chunk_seq_id,
                # constructed metadata...
                'formId': f'{form_id}', # pulled from the filename
                'chunkId': f'{form_id}-{i}-chunk{chunk_seq_id:04d}',
                # metadata from file...
                'character': df['Character'],
                'movie': df['First Movie'],
                'year': df['Year'],
                'source': df['Source'],
            })
            chunk_seq_id += 1
        print(f'\tSplit into {chunk_seq_id} chunks')
    return chunks_with_metadata

# %%
first_file_chunks = split_data_from_file(df)
# Out:
# Processing 0
# 	Split into 38 chunks
# Processing 1
# 	Split into 33 chunks
# Processing 2
# 	Split into 28 chunks
# Processing 3
# 	Split into 1 chunks
# Processing 4
# 	Split into 1 chunks
# Processing 5
# 	Split into 1 chunks
# Processing 6
# 	Split into 1 chunks
# Processing 7
# 	Split into 1 chunks
# Processing 8
# 	Split into 1 chunks
# Processing 9
# 	Split into 1 chunks
# Processing 10
# 	Split into 1 chunks
# Processing 11
# 	Split into 1 chunks
# Processing 12
# 	Split into 1 chunks
# Processing 13
# 	Split into 1 chunks
# Processing 14
# 	Split into 1 chunks
# Processing 15
# 	Split into 1 chunks
# Processing 16
# 	Split into 1 chunks
# Processing 17
# 	Split into 1 chunks
# Processing 18
# 	Split into 1 chunks
# Processing 19
# 	Split into 1 chunks
# Processing 20
# 	Split into 1 chunks
# Processing 21
# 	Split into 1 chunks
# Processing 22
# 	Split into 1 chunks
# Processing 23
# 	Split into 1 chunks
# Processing 24
# 	Split into 1 chunks
# Processing 25
# 	Split into 1 chunks
# Processing 26
# 	Split into 1 chunks
# Processing 27
# 	Split into 1 chunks
# Processing 28
# 	Split into 1 chunks
# Processing 29
# 	Split into 1 chunks
# Processing 30
# 	Split into 1 chunks
# Processing 31
# 	Split into 1 chunks
# Processing 32
# 	Split into 1 chunks
# Processing 33
# 	Split into 1 chunks
# Processing 34
# 	Split into 1 chunks
# Processing 35
# 	Split into 1 chunks
# Processing 36
# 	Split into 1 chunks
# Processing 37
# 	Split into 1 chunks
# Processing 38
# 	Split into 1 chunks
# Processing 39
# 	Split into 1 chunks

# %%
len(first_file_chunks)
# Out:
# 136

# %%
len(first_file_chunks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 len(first_file_chunks)
#
# NameError: name 'first_file_chunks' is not defined

# %%
cypher = """
MATCH (n)
DETACH DELETE n
"""
kg.query(cypher)
# Out:
# []

# %%
merge_chunk_node_query = """
MERGE(mergedChunk:Chunk {chunkId: $chunkParam.chunkId})
    ON CREATE SET 
        mergedChunk.names = $chunkParam.names,
        mergedChunk.first_movie = $chunkParam.first_movie, 
        mergedChunk.year = $chunkParam.year,
        mergedChunk.chunkSeqId = $chunkParam.chunkSeqId, 
        mergedChunk.text = $chunkParam.text,
        mergedChunk.source = $chunkParam.source
RETURN mergedChunk
"""

# %%
kg.query(merge_chunk_node_query, 
         params={'chunkParam':first_file_chunks[0]})
# Out:
# [{'mergedChunk': {'names': 'Luke Skywalker',
#    'first_movie': 'Star Wars: A New Hope',
#    'year': 1977,
#    'text': 'Luke Skywalker is one of the most iconic characters in cinematic history, originating from the classic “Star Wars” franchise. His journey from a farm boy on the remote desert planet of Tatooine to the',
#    'source': 'source',
#    'chunkId': 'Row0-chunk0000',
#    'chunkSeqId': 0}}]

# %%
kg.query("""
CREATE CONSTRAINT unique_chunk IF NOT EXISTS 
    FOR (c:Chunk) REQUIRE c.chunkId IS UNIQUE
""")
# Out:
# []

# %%
node_count = 0
for chunk in first_file_chunks:
    print(f"Creating `:Chunk` node for chunk ID {chunk['chunkId']}")
    kg.query(merge_chunk_node_query, 
            params={
                'chunkParam': chunk
            })
    node_count += 1
print(f"Created {node_count} nodes")
# Out:
# Creating `:Chunk` node for chunk ID Row0-chunk0000
# Creating `:Chunk` node for chunk ID Row0-chunk0001
# Creating `:Chunk` node for chunk ID Row0-chunk0002
# Creating `:Chunk` node for chunk ID Row0-chunk0003
# Creating `:Chunk` node for chunk ID Row0-chunk0004
# Creating `:Chunk` node for chunk ID Row0-chunk0005
# Creating `:Chunk` node for chunk ID Row0-chunk0006
# Creating `:Chunk` node for chunk ID Row0-chunk0007
# Creating `:Chunk` node for chunk ID Row0-chunk0008
# Creating `:Chunk` node for chunk ID Row0-chunk0009
# Creating `:Chunk` node for chunk ID Row0-chunk0010
# Creating `:Chunk` node for chunk ID Row0-chunk0011
# Creating `:Chunk` node for chunk ID Row0-chunk0012
# Creating `:Chunk` node for chunk ID Row0-chunk0013
# Creating `:Chunk` node for chunk ID Row0-chunk0014
# Creating `:Chunk` node for chunk ID Row0-chunk0015
# Creating `:Chunk` node for chunk ID Row0-chunk0016
# Creating `:Chunk` node for chunk ID Row0-chunk0017
# Creating `:Chunk` node for chunk ID Row0-chunk0018
# Creating `:Chunk` node for chunk ID Row0-chunk0019
# Creating `:Chunk` node for chunk ID Row0-chunk0020
# Creating `:Chunk` node for chunk ID Row0-chunk0021
# Creating `:Chunk` node for chunk ID Row0-chunk0022
# Creating `:Chunk` node for chunk ID Row0-chunk0023
# Creating `:Chunk` node for chunk ID Row0-chunk0024
# Creating `:Chunk` node for chunk ID Row0-chunk0025
# Creating `:Chunk` node for chunk ID Row0-chunk0026
# Creating `:Chunk` node for chunk ID Row0-chunk0027
# Creating `:Chunk` node for chunk ID Row0-chunk0028
# Creating `:Chunk` node for chunk ID Row0-chunk0029
# Creating `:Chunk` node for chunk ID Row0-chunk0030
# Creating `:Chunk` node for chunk ID Row0-chunk0031
# Creating `:Chunk` node for chunk ID Row0-chunk0032
# Creating `:Chunk` node for chunk ID Row0-chunk0033
# Creating `:Chunk` node for chunk ID Row0-chunk0034
# Creating `:Chunk` node for chunk ID Row0-chunk0035
# Creating `:Chunk` node for chunk ID Row0-chunk0036
# Creating `:Chunk` node for chunk ID Row0-chunk0037
# Creating `:Chunk` node for chunk ID Row1-chunk0000
# Creating `:Chunk` node for chunk ID Row1-chunk0001
# Creating `:Chunk` node for chunk ID Row1-chunk0002
# Creating `:Chunk` node for chunk ID Row1-chunk0003
# Creating `:Chunk` node for chunk ID Row1-chunk0004
# Creating `:Chunk` node for chunk ID Row1-chunk0005
# Creating `:Chunk` node for chunk ID Row1-chunk0006
# Creating `:Chunk` node for chunk ID Row1-chunk0007
# Creating `:Chunk` node for chunk ID Row1-chunk0008
# Creating `:Chunk` node for chunk ID Row1-chunk0009
# Creating `:Chunk` node for chunk ID Row1-chunk0010
# Creating `:Chunk` node for chunk ID Row1-chunk0011
# Creating `:Chunk` node for chunk ID Row1-chunk0012
# Creating `:Chunk` node for chunk ID Row1-chunk0013
# Creating `:Chunk` node for chunk ID Row1-chunk0014
# Creating `:Chunk` node for chunk ID Row1-chunk0015
# Creating `:Chunk` node for chunk ID Row1-chunk0016
# Creating `:Chunk` node for chunk ID Row1-chunk0017
# Creating `:Chunk` node for chunk ID Row1-chunk0018
# Creating `:Chunk` node for chunk ID Row1-chunk0019
# Creating `:Chunk` node for chunk ID Row1-chunk0020
# Creating `:Chunk` node for chunk ID Row1-chunk0021
# Creating `:Chunk` node for chunk ID Row1-chunk0022
# Creating `:Chunk` node for chunk ID Row1-chunk0023
# Creating `:Chunk` node for chunk ID Row1-chunk0024
# Creating `:Chunk` node for chunk ID Row1-chunk0025
# Creating `:Chunk` node for chunk ID Row1-chunk0026
# Creating `:Chunk` node for chunk ID Row1-chunk0027
# Creating `:Chunk` node for chunk ID Row1-chunk0028
# Creating `:Chunk` node for chunk ID Row1-chunk0029
# Creating `:Chunk` node for chunk ID Row1-chunk0030
# Creating `:Chunk` node for chunk ID Row1-chunk0031
# Creating `:Chunk` node for chunk ID Row1-chunk0032
# Creating `:Chunk` node for chunk ID Row2-chunk0000
# Creating `:Chunk` node for chunk ID Row2-chunk0001
# Creating `:Chunk` node for chunk ID Row2-chunk0002
# Creating `:Chunk` node for chunk ID Row2-chunk0003
# Creating `:Chunk` node for chunk ID Row2-chunk0004
# Creating `:Chunk` node for chunk ID Row2-chunk0005
# Creating `:Chunk` node for chunk ID Row2-chunk0006
# Creating `:Chunk` node for chunk ID Row2-chunk0007
# Creating `:Chunk` node for chunk ID Row2-chunk0008
# Creating `:Chunk` node for chunk ID Row2-chunk0009
# Creating `:Chunk` node for chunk ID Row2-chunk0010
# Creating `:Chunk` node for chunk ID Row2-chunk0011
# Creating `:Chunk` node for chunk ID Row2-chunk0012
# Creating `:Chunk` node for chunk ID Row2-chunk0013
# Creating `:Chunk` node for chunk ID Row2-chunk0014
# Creating `:Chunk` node for chunk ID Row2-chunk0015
# Creating `:Chunk` node for chunk ID Row2-chunk0016
# Creating `:Chunk` node for chunk ID Row2-chunk0017
# Creating `:Chunk` node for chunk ID Row2-chunk0018
# Creating `:Chunk` node for chunk ID Row2-chunk0019
# Creating `:Chunk` node for chunk ID Row2-chunk0020
# Creating `:Chunk` node for chunk ID Row2-chunk0021
# Creating `:Chunk` node for chunk ID Row2-chunk0022
# Creating `:Chunk` node for chunk ID Row2-chunk0023
# Creating `:Chunk` node for chunk ID Row2-chunk0024
# Creating `:Chunk` node for chunk ID Row2-chunk0025
# Creating `:Chunk` node for chunk ID Row2-chunk0026
# Creating `:Chunk` node for chunk ID Row2-chunk0027
# Creating `:Chunk` node for chunk ID Row3-chunk0000
# Creating `:Chunk` node for chunk ID Row4-chunk0000
# Creating `:Chunk` node for chunk ID Row5-chunk0000
# Creating `:Chunk` node for chunk ID Row6-chunk0000
# Creating `:Chunk` node for chunk ID Row7-chunk0000
# Creating `:Chunk` node for chunk ID Row8-chunk0000
# Creating `:Chunk` node for chunk ID Row9-chunk0000
# Creating `:Chunk` node for chunk ID Row10-chunk0000
# Creating `:Chunk` node for chunk ID Row11-chunk0000
# Creating `:Chunk` node for chunk ID Row12-chunk0000
# Creating `:Chunk` node for chunk ID Row13-chunk0000
# Creating `:Chunk` node for chunk ID Row14-chunk0000
# Creating `:Chunk` node for chunk ID Row15-chunk0000
# Creating `:Chunk` node for chunk ID Row16-chunk0000
# Creating `:Chunk` node for chunk ID Row17-chunk0000
# Creating `:Chunk` node for chunk ID Row18-chunk0000
# Creating `:Chunk` node for chunk ID Row19-chunk0000
# Creating `:Chunk` node for chunk ID Row20-chunk0000
# Creating `:Chunk` node for chunk ID Row21-chunk0000
# Creating `:Chunk` node for chunk ID Row22-chunk0000
# Creating `:Chunk` node for chunk ID Row23-chunk0000
# Creating `:Chunk` node for chunk ID Row24-chunk0000
# Creating `:Chunk` node for chunk ID Row25-chunk0000
# Creating `:Chunk` node for chunk ID Row26-chunk0000
# Creating `:Chunk` node for chunk ID Row27-chunk0000
# Creating `:Chunk` node for chunk ID Row28-chunk0000
# Creating `:Chunk` node for chunk ID Row29-chunk0000
# Creating `:Chunk` node for chunk ID Row30-chunk0000
# Creating `:Chunk` node for chunk ID Row31-chunk0000
# Creating `:Chunk` node for chunk ID Row32-chunk0000
# Creating `:Chunk` node for chunk ID Row33-chunk0000
# Creating `:Chunk` node for chunk ID Row34-chunk0000
# Creating `:Chunk` node for chunk ID Row35-chunk0000
# Creating `:Chunk` node for chunk ID Row36-chunk0000
# Creating `:Chunk` node for chunk ID Row37-chunk0000
# Creating `:Chunk` node for chunk ID Row38-chunk0000
# Creating `:Chunk` node for chunk ID Row39-chunk0000
# Created 136 nodes

# %%
kg.query("""
         MATCH (n)
         RETURN count(n) as nodeCount
         """)
# Out:
# [{'nodeCount': 136}]

# %%
import ollama

# %%
ollama.embeddings(
  model='nomic-embed-text',
  prompt='Llamas are members of the camelid family',
)["embedding"]
# Out:
# [0.31635236740112305,
#  0.31518685817718506,
#  -3.466998815536499,
#  -1.234925389289856,
#  0.3010212481021881,
#  0.009775924496352673,
#  -1.8029427528381348,
#  -1.6415399312973022,
#  -0.8765112161636353,
#  -0.12759114801883698,
#  -0.15461255609989166,
#  1.040388822555542,
#  1.528531789779663,
#  0.37732094526290894,
#  0.8571701049804688,
#  -0.45799967646598816,
#  -1.3164403438568115,
#  -0.3816385865211487,
#  0.9066450595855713,
#  0.5386151075363159,
#  -1.3993167877197266,
#  0.9144339561462402,
#  0.2063274085521698,
#  -0.5301305055618286,
#  1.3448079824447632,
#  -0.21487903594970703,
#  -0.537859320640564,
#  1.0648365020751953,
#  0.1113395094871521,
#  -0.44637155532836914,
#  1.9089592695236206,
#  0.21950259804725647,
#  0.3856092691421509,
#  -0.5520491600036621,
#  0.12302646040916443,
#  0.6421322822570801,
#  2.0016045570373535,
#  0.7191365957260132,
#  1.7278251647949219,
#  0.34708428382873535,
#  1.357598066329956,
#  -0.1952972412109375,
#  0.6919195055961609,
#  0.36098405718803406,
#  1.0728297233581543,
#  -0.8790739178657532,
#  1.0016108751296997,
#  0.9795132875442505,
#  2.023308038711548,
#  -0.2934916615486145,
#  0.818692684173584,
#  -0.7465351223945618,
#  -0.25063884258270264,
#  0.30421876907348633,
#  0.597033679485321,
#  -0.005717113614082336,
#  0.2001754194498062,
#  0.2037896066904068,
#  -0.24209126830101013,
#  0.8744218349456787,
#  -0.169364795088768,
#  -0.06856304407119751,
#  0.36315834522247314,
#  -1.3847246170043945,
#  -1.5859984159469604,
#  0.9987197518348694,
#  0.539485514163971,
#  -0.6098141670227051,
#  -0.05350387468934059,
#  -0.5901960134506226,
#  0.2554244101047516,
#  -0.6282570362091064,
#  0.3998138904571533,
#  0.756522536277771,
#  1.3070716857910156,
#  0.2719137370586395,
#  0.23162052035331726,
#  -0.14910589158535004,
#  -0.630125105381012,
#  -0.5302132368087769,
#  -0.3080999553203583,
#  -1.286971092224121,
#  1.1172575950622559,
#  -0.7332683801651001,
#  0.6203982830047607,
#  -1.2780869007110596,
#  -0.28960973024368286,
#  -1.6811919212341309,
#  -0.2907242178916931,
#  -0.6224489212036133,
#  0.07129575312137604,
#  -0.2876918613910675,
#  0.14125379920005798,
#  0.09164663404226303,
#  -0.1307072788476944,
#  1.80802583694458,
#  -0.38346952199935913,
#  0.67580646276474,
#  0.3487092852592468,
#  0.9662595987319946,
#  0.18761345744132996,
#  -1.2848817110061646,
#  -0.21682992577552795,
#  1.6210933923721313,
#  0.36320260167121887,
#  0.09831292182207108,
#  -1.507917881011963,
#  0.8661155700683594,
#  -0.9071447253227234,
#  1.6704144477844238,
#  0.9108259081840515,
#  -0.7498851418495178,
#  -1.0829193592071533,
#  0.048012301325798035,
#  0.21732163429260254,
#  0.25461167097091675,
#  1.0935685634613037,
#  -0.5329092741012573,
#  0.8298923373222351,
#  -0.053096093237400055,
#  -0.6581243276596069,
#  -1.2433738708496094,
#  0.7678220272064209,
#  -2.244144916534424,
#  0.08103035390377045,
#  -0.7790936231613159,
#  0.5477728247642517,
#  0.15393611788749695,
#  -0.3176121711730957,
#  0.35186654329299927,
#  -0.036721110343933105,
#  0.08758525550365448,
#  -0.83837890625,
#  -0.00587821751832962,
#  0.7950479984283447,
#  0.024221956729888916,
#  -0.7790892124176025,
#  -0.11093069612979889,
#  -0.29302287101745605,
#  0.5886318683624268,
#  1.0897040367126465,
#  -1.5092523097991943,
#  -0.6515430212020874,
#  0.9157581925392151,
#  0.4455363154411316,
#  0.36900442838668823,
#  0.2921289801597595,
#  -0.861952543258667,
#  0.014099419116973877,
#  -0.391049325466156,
#  0.0461878627538681,
#  0.049048177897930145,
#  -0.809796929359436,
#  0.5054280757904053,
#  0.7644680142402649,
#  -0.31460511684417725,
#  1.5056748390197754,
#  -0.08730398863554001,
#  1.1470625400543213,
#  0.17059844732284546,
#  -1.4843387603759766,
#  -0.8018018007278442,
#  -1.8099603652954102,
#  -1.376747965812683]

# %%
kg.query("""DROP INDEX form_10k_chunks""")
# Out:
# []

# %%
kg.query("""
         CREATE VECTOR INDEX `form_10k_chunks` IF NOT EXISTS
          FOR (c:Chunk) ON (c.textEmbedding) 
          OPTIONS { indexConfig: {
            `vector.dimensions`: 768,
            `vector.similarity_function`: 'cosine'    
         }}
""")
# Out:
# []

# %%
import ollama

# %%
def get_ollama_embedding(text):
    return ollama.embeddings(model='nomic-embed-text', prompt=text)["embedding"]

kg.query("""
    MATCH (chunk:Chunk) WHERE chunk.textEmbedding IS NULL
    WITH chunk
    CALL db.create.setNodeVectorProperty(chunk, "textEmbedding", $vector)
    """, 
    params={"vector": get_ollama_embedding(chunk['text'])}
)
# Out:
# []

# %%
kg.refresh_schema()
print(kg.schema)
# Out:
# Node properties:
# Chunk {source: STRING, first_movie: STRING, textEmbedding: LIST, chunkId: STRING, year: INTEGER, chunkSeqId: INTEGER, text: STRING, names: STRING}
# Relationship properties:
#
# The relationships:

# %%
def neo4j_vector_search(question):
    """Search for similar nodes using the Neo4j vector index."""
    question_embedding = get_ollama_embedding(question)
    
    vector_search_query = """
      CALL db.index.vector.queryNodes($index_name, $top_k, $question_embedding) yield node, score
      RETURN score, node.text AS text
    """
    
    similar = kg.query(vector_search_query, 
                       params={
                        'question_embedding': question_embedding,
                        'index_name': 'form_10k_chunks', 
                        'top_k': 10})
    
    return similar

# %%
search_results = neo4j_vector_search(
    'In a single sentence, who is Luke Skywalker.'
)

# %%
search_results
# Out:
# [{'score': 0.7761154174804688,
#   'text': 'In “Return of the Jedi,” Luke emerges as a fully-fledged Jedi Knight. His mission to redeem his father and defeat the Emperor becomes the central focus of his story. Luke’s compassion and refusal to'},
#  {'score': 0.7761154174804688,
#   'text': 'and refusal to give up on Anakin Skywalker ultimately lead to the redemption of his father and the downfall of the Sith. By rejecting the Emperor’s temptation to turn to the dark side, Luke proves'},
#  {'score': 0.7761154174804688,
#   'text': 'side, Luke proves himself to be the embodiment of the Jedi ideals of hope, selflessness, and the belief in the goodness of others. His final confrontation with Darth Vader is not just a physical'},
#  {'score': 0.7761154174804688,
#   'text': 'not just a physical battle but a test of his character and faith in the light side of the Force.'},
#  {'score': 0.7761154174804688,
#   'text': 'After the defeat of the Empire, Luke goes on to rebuild the Jedi Order, though this process is fraught with difficulties. His journey is expanded in the sequel trilogy, where we see an older,'},
#  {'score': 0.7761154174804688,
#   'text': 'we see an older, disillusioned Luke, who has gone into self-imposed exile after a disastrous attempt to train a new generation of Jedi. The rise of Kylo Ren (Ben Solo, Luke’s nephew) and the fall of'},
#  {'score': 0.7761154174804688,
#   'text': 'and the fall of his Jedi students deeply affects Luke, leading him to question the legacy of the Jedi and his role in the galaxy’s ongoing conflict. Despite his initial reluctance, Luke returns to'},
#  {'score': 0.7761154174804688,
#   'text': 'Luke returns to the fight in “The Last Jedi” by projecting his Force presence to confront Kylo Ren and inspire the Resistance. His sacrifice allows the remnants of the Resistance to escape, and his'},
#  {'score': 0.7761154174804688,
#   'text': 'to escape, and his legend grows even further, solidifying his place as one of the galaxy’s greatest heroes.'},
#  {'score': 0.7761154174804688,
#   'text': 'must decide whether to follow the path of the Jedi or risk falling to the dark side, as his father did.'}]

# %%
class OllamaEmbeddings:
    """Custom embeddings class for generating embeddings using the local Ollama model."""
    
    def __init__(self, model_name='nomic-embed-text'):
        self.model_name = model_name

    def embed_query(self, text):
        """Generate embeddings for a single text input using Ollama."""
        result = ollama.embeddings(model=self.model_name, prompt=text)
        
        if isinstance(result, dict) and 'embedding' in result:
            embedding = result['embedding']
            if isinstance(embedding, list) and all(isinstance(x, (float, int)) for x in embedding):
                return embedding
            else:
                raise ValueError("Ollama embedding is not a valid numerical array.")
        else:
            raise ValueError("Failed to retrieve embedding from Ollama.")

    def embed_documents(self, texts):
        """Generate embeddings for a list of documents."""
        return [self.embed(text) for text in texts]

# %%
# Global constants
VECTOR_INDEX_NAME = 'form_10k_chunks'
VECTOR_NODE_LABEL = 'Chunk'
VECTOR_SOURCE_PROPERTY = 'text'
VECTOR_EMBEDDING_PROPERTY = 'textEmbedding'

# %%
ollama_embeddings = OllamaEmbeddings(model_name='nomic-embed-text')

neo4j_vector_store = Neo4jVector.from_existing_graph(
    embedding=ollama_embeddings,
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    index_name=VECTOR_INDEX_NAME,
    node_label=VECTOR_NODE_LABEL,
    text_node_properties=[VECTOR_SOURCE_PROPERTY],
    embedding_node_property=VECTOR_EMBEDDING_PROPERTY,
)

# %%
retriever = neo4j_vector_store.as_retriever()

# %%
class OllamaChat:
    """Custom chat class for generating responses using the local Ollama model."""
    
    def __init__(self, model_name='llama3.2'):
        self.model_name = model_name

    def __call__(self, prompt):
        """Make the class callable by implementing the __call__ method."""
        return self.chat(prompt)

    def chat(self, prompt):
        """Generate a response using the local Ollama model."""
        result = ollama.chat(model=self.model_name, messages=[{'role': 'user', 'content': prompt}])
        
        if isinstance(result, dict) and 'response' in result:
            return result['message']['content']
        else:
            raise ValueError("Failed to retrieve response from Ollama.")

# %%
from langchain.llms.base import LLM
from typing import List

class OllamaLLM(LLM):
    """Custom LLM class to interface with the local Ollama model."""

    model_name: str = "llama3.2"

    def _call(self, prompt: str, stop: List[str] = None) -> str:
        """Generate a response from the Ollama model."""
        result = ollama.chat(model=self.model_name, messages=[{'role': 'user', 'content': prompt}], stream=False)
        
        if isinstance(result, dict) and 'message' in result and 'content' in result['message']:
            return result['message']['content']
        else:
            raise ValueError(f"Failed to retrieve response from Ollama. Result: {result}")

    @property
    def _identifying_params(self) -> dict:
        """Return the identifying parameters of the model."""
        return {"model_name": self.model_name}
    
    @property
    def _llm_type(self) -> str:
        """Return the type of the LLM as required by the LangChain framework."""
        return "ollama"

# %%
ollama_llm = OllamaLLM(model_name='llama3.2')

chain = RetrievalQAWithSourcesChain.from_chain_type(
    llm=ollama_llm,
    chain_type="stuff", 
    retriever=retriever
)

def prettychain(question: str) -> str:
    """Pretty print the chain's response to a question"""
    response = chain({"question": question}, return_only_outputs=True)
    
    print(textwrap.fill(response['answer'], 60))
    
    # # Optionally, you can also print the sources if needed
    # if 'sources' in response:
    #     print("\nSources:")
    #     for source in response['sources']:
    #         print(source)

# %%
prettychain("Who is Luke Skywalker?")
# Out:
# I don't know who Luke Skywalker is.
